# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import datetime
run1 = pd.read_csv("test_logs/2016-07-01_run1.csv")#, 
#                    parse_dates=["time"],
#                    date_parser=datetime.datetime.fromtimestamp)
run1["time"] = run1["time"].apply(lambda x: datetime.datetime.fromtimestamp(x))

# %%
run1.rpm.plot()
figure()
run1.ds_volt.plot()
run1.an_volt.plot(secondary_y=True)
figure()
run1.ds_cur_300v.plot()
run1.an_cur_300v.plot(secondary_y=True)
figure()
run1.ds_bat_cur.plot()
figure()
run1.soc.plot()
figure()
run1.ds_cur_48v.plot()
